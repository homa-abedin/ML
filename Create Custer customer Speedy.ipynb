# %% [markdown]
# <a href="https://colab.research.google.com/github/homa-abedin/ML/blob/master/Create%20Custer%20customer%20Speedy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
data= pd.read_csv("ScriptCustomerSales1.csv")
data
# Out:
#         customercode     salesarea customergroup  productnumber  \
# 0             100006  مویرگی تلفنی      اتوسرویس           31.0
# 1             100006  مویرگی تلفنی      اتوسرویس         3813.0
# 2             100006  مویرگی تلفنی      اتوسرویس         3813.0
# 3             100006  مویرگی تلفنی      اتوسرویس         6223.0
# 4             100006  مویرگی تلفنی      اتوسرویس         6223.0
# ...              ...           ...           ...            ...
# 446297        400019  مویرگی تلفنی      اتوسرویس         6613.0
# 446298        400019  مویرگی تلفنی      اتوسرویس         6641.0
# 446299        400019  مویرگی تلفنی      اتوسرویس         6641.0
# 446300        400019  مویرگی تلفنی      اتوسرویس         6642.0
# 446301        400019  مویرگی حضوری             ا            NaN
#
#         productweight      Amount
# 0                 0.1         1.0
# 1                17.4  21353237.0
# 2                17.4  21353155.0
# 3                90.0  36696263.0
# ...

# %%
data.shape
# Out:
# (446302, 6)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe()
# Out:
#         customercode  productnumber  productweight        Amount
# count  446302.000000   4.463010e+05  446299.000000  4.463010e+05
# mean   159329.765569   7.353476e+05      94.199665  4.753285e+07
# std     71585.576282   6.576105e+06     190.616101  8.829477e+07
# min    100006.000000   6.000000e+00     -69.760000 -3.350000e+02
# 25%    106272.000000   6.222000e+03      21.600000  1.395704e+07
# 50%    110617.000000   6.308000e+03      43.200000  2.474507e+07
# 75%    202355.000000   6.362000e+03      90.000000  5.039751e+07
# max    400019.000000   6.001000e+07   14652.000000  7.391879e+09

# %%
data.dtypes
# Out:
# customercode       int64
# salesarea         object
# customergroup     object
# productnumber    float64
# productweight    float64
# Amount           float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=LE.fit_transform (data[i])
        data[i]=LE.transform (df_test[i])
